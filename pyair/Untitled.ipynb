# %%
from prophet import *
get_prophet()
# Out:
# Year?
# > 2017
# Pollutant type?
# > PM2.5_24h
# start date? (in the format as 20190101-00)
# > 20170101-00
# end date? in the format as 20191231-23)
# > 20171201-00
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
#                            date  hour       type  Beijing  Tianjin  Tangshan  \
# 2017-01-01 00:00:00  20170101.0   0.0  PM2.5_24h    301.0    266.0     324.0
# 2017-01-01 01:00:00  20170101.0   1.0  PM2.5_24h    306.0    255.0     323.0
# 2017-01-01 02:00:00  20170101.0   2.0  PM2.5_24h    312.0    255.0     322.0
# 2017-01-01 03:00:00  20170101.0   3.0  PM2.5_24h    317.0    257.0     317.0
# 2017-01-01 04:00:00  20170101.0   4.0  PM2.5_24h    323.0    266.0     314.0
# 2017-01-01 05:00:00  20170101.0   5.0  PM2.5_24h    330.0    264.0     317.0
# 2017-01-01 06:00:00  20170101.0   6.0  PM2.5_24h    337.0    262.0     313.0
# 2017-01-01 07:00:00  20170101.0   7.0  PM2.5_24h    346.0    259.0     308.0
# ...
