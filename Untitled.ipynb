# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/Users/yanaustin/code/AustinYan0808/accurateair/lists/work_station_data.csv')
df
# Out:
#            city station name province  station_id  latitude (', '')  \
# 0       Beijing           北京       北京      545110              3948
# 1       Tianjin           天津       天津      545270              3905
# 2      Tangshan           唐山       河北      545340              3939
# 3       Baoding           保定       河北      546020              3844
# 4   Zhangjiakou          张家口       河北      544010              4046
# ..          ...          ...      ...         ...               ...
# 92     Hanzhong           汉中       陕西      571270              3304
# 93        Yulin           榆林       陕西      536460              3816
# 94       Ankang           安康       陕西      572450              3243
# 95      Zhangye           张掖       甘肃      526520              3905
# 96      Jiuquan           酒泉       甘肃      525330              3946
#
#     longitude (', ")  Elevation (m)
# 0            11628.0           32.5
# 1            11703.0            4.3
# 2            11806.0           24.5
# ...

# %%
df.columns = ['city','station name','province',
                     'station_id','latitude','longitude','Elevation']

# %%
df
# Out:
#            city station name province  station_id  latitude  longitude  \
# 0       Beijing           北京       北京      545110      3948    11628.0
# 1       Tianjin           天津       天津      545270      3905    11703.0
# 2      Tangshan           唐山       河北      545340      3939    11806.0
# 3       Baoding           保定       河北      546020      3844    11529.0
# 4   Zhangjiakou          张家口       河北      544010      4046    11455.0
# ..          ...          ...      ...         ...       ...        ...
# 92     Hanzhong           汉中       陕西      571270      3304    10702.0
# 93        Yulin           榆林       陕西      536460      3816    10947.0
# 94       Ankang           安康       陕西      572450      3243    10902.0
# 95      Zhangye           张掖       甘肃      526520      3905    10017.0
# 96      Jiuquan           酒泉       甘肃      525330      3946     9829.0
#
#     Elevation
# 0        32.5
# 1         4.3
# 2        24.5
# 3        17.9
# 4       774.1
# ..        ...
# ...

# %%
df.plot(kind='scatter',x='longitude',y='latitude',cmap='inferno',colorbar=True,alpha=0.8,figsize=(20,10))
